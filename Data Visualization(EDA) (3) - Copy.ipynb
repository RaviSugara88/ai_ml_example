# %% [markdown]
# #  Matplotlib Tutorial
#
#
#
# * Matplotlib is (Ravi)a plotting library for the Python Programming language and its numerical mathematics  extension Numpy.
#
# * It is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.
#
# * One of the greatest benefits of visualization is that it allows us visual access to huge amounts of data in easily digestible visuals.
#
# * Matplotlib consists of several plots like line, bar, scatter, histogram etc.

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt

# %matplotlib.inline # To avoid plt.show()
# Exploratory Data Analysis
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
import numpy as np

# %%
## Simple Example
x = np.arange(0,10)
y = np.arange(40,50)

# %% [markdown]
# #  Plotting using Matplotlib..

# %%
# Scatter Plot
# Press (Shift + Tab)
plt.scatter(x,y,c = "g") #(X-axis,y-axis,s is in pixel, c is colour)
plt.xlabel('X axis') 
plt.ylabel('Y axis')
plt.title('Graph in 2D')
plt.savefig("Test.png")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # #  Line Plot

# %%
x = np.arange(0,10)
y = x*x
plt.plot()

# %%
plt.plot(x,y, "*-",linestyle = "dashed",linewidth= 5,markersize = 10) # USe r-,r--,r*-,ro,ro--
plt.xlabel("X axis") # Checking the parameters..
plt.ylabel("Y axis")
plt.title(" 2-D Plot")
# Out:
# Text(0.5, 1.0, ' 2-D Plot')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
x = np.array([1,2,3,4,5])
y = np.array([22 ,33,44,55,66])
sns.regplot(x = x,y = y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
np.pi # 3.142
# Out:
# 3.141592653589793

# %%
# Compute the x and y coordinates for points on a size curve

x = np.arange(0,4* np.pi,0.1) # From 0 to a particular value,stepsize

y = np.sin(x) # Sine is a function which will find sine of x values

plt.title("sine wave form") # Example of Complex Figure

# plot the points using matplotlib
plt.plot(x,y)
plt.show()
pd.

# %% [markdown]
# #        Line plot :

# %%
# importing matplotlib module 
from matplotlib import pyplot as plt
  
# x-axis values
x = [55, 62, 59, 45, 70]
  
# Y-axis values
y = [100, 102, 180, 140, 126]
  
# Function to plot
plt.plot(x,y)
  
# function to show the plot
plt.show()

# %% [markdown]
# #  Bar plot :

# %%
from matplotlib import pyplot as plt

# create a dataset
height = [3, 22, 5, 18, 45]
bars = ('A', 'B', 'C', 'D', 'E')

# Create bars
plt.bar(bars, height, color=('black', 'red', 'green', 'blue', 'cyan'))

# Create names on the x-axis
plt.xticks(bars)
plt.yticks(height)
# Show graph
plt.show()

# %% [markdown]
# # Histogram :

# %%
x = np.random.normal(120, 20, 550) 
x
# Out:
# array([ 98.89619627, 116.56886187,  98.08034494, 130.58064148,
#        111.17819214, 114.5204273 ,  94.89355918, 114.54228783,
#        129.31411799, 103.80571034, 107.00344141, 127.33098262,
#        125.18512704, 124.2251313 , 123.87700403, 126.2742415 ,
#        126.17940658, 121.68712513, 147.75493929, 101.32391858,
#        125.45563812, 100.28620166, 103.34724619, 128.43331481,
#        124.19734319, 111.72048789, 106.43842383, 110.70939868,
#        118.53878174, 114.53880995, 116.0567079 , 135.9004797 ,
#        111.88630985, 120.30539577, 108.58106278, 162.4151274 ,
#         88.56612276, 111.43393653, 117.76821059,  88.15591726,
#        142.36654336, 137.67109698,  84.94858536,  93.16992648,
#        127.60301001, 131.49100489, 134.30116054, 146.13548669,
#        169.61688112, 112.55828988, 138.07476998,  79.42944844,
#        127.01257378, 150.05613725, 129.52004524, 113.7585262 ,
#        111.60094617, 103.61760069, 133.09641088, 143.22837124,
# ...

# %%
# importing matplotlib module 
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(120, 20, 550) # it is used to gets the random samples from a normal distribution.
# mean, std, size of array
plt.hist(x)
plt.xlabel("bvbvcxn")
plt.ylabel("vbhbv")
plt.show()

# %% [markdown]
# # Scatter Plot :

# %%
# importing matplotlib module 
from matplotlib import pyplot as plt
import numpy as np  
# x-axis values
x = np.random.random(10)# Return random floats in the interval [0.0, 1.0]
  
# Y-axis values
y = np.random.randint(low = 10, high = 30, size = 10)# Return random integers from low to high .
  
# Function to plot scatter
plt.scatter(x, y)
  
# function to show the plot
plt.show()

# %% [markdown]
# # Seaborn
#
# * Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# *  It is built on the top of matplotlib library and also closely integrated to the data structures from pandas.

# %% [markdown]
# # Different categories of plot in Seaborn
#
# * Plots are basically used for visualizing the relationship between variables. Those variables can be either be completely numerical or a category like a group, class or division. Seaborn divides plot into the below categories –
#
#
# * Relational plots: This plot is used to understand the relation between two variables.
#
# * Categorical plots: This plot deals with categorical variables and how they can be visualized.
#
# * Distribution plots: This plot is used for examining univariate and bivariate distributions.
#
# * Regression plots: The regression plots in seaborn are primarily intended to add a visual guide that helps to emphasize patterns in a dataset during exploratory data analyses.
#
# * Matrix plots: A matrix plot is an array of scatterplots.

# %%
# Importing libraries
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ##   Dist plot :  Seaborn dist plot  is used to plot a histogram, with some other variations like          kdeplot and rugplot.

# %%
sns.set(style="darkgrid")
fmri = sns.load_dataset("fmri")
fmri.tail(3)
# Out:
#      subject  timepoint event    region    signal
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899

# %%
d = np.random.normal(12,5,112)
sns.kdeplot(d)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Selecting style as white,
# dark, whitegrid, darkgrid ,white
import seaborn as sns 
import numpy as np
sns.set(style="darkgrid")
# Generate a random univariate 
# dataset
d = np.random.normal(12,5,112)#(mean,std,count)
  
# Plot a simple histogram and kde 
# with binsize determined automatically
sns.distplot(d, kde=True, color="g") # try kde = False
# kde --> kernel density estimator
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.set(style="whitegrid") # dark,darkgrid,white
a = np.random.RandomState(100) 
b = a.normal(size = 200)
sns.distplot(b,kde = True,color = "red") #kde --Kernel Density Estimator
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(b)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.rugplot(b,height = 0.2)
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns; 
sns.set_theme(style = "dark")
tips = sns.load_dataset("tips")
sns.kdeplot(data=tips, x="total_bill")
sns.rugplot(data=tips, x="total_bill",height = 0.2)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# # Line plot : The line plot is one of the most basic plot in seaborn library.
#
# *  This plot is mainly used to visualize the data in form of some time series, i.e. in continuous manner.

# %%
import seaborn as sns
sns.set(style="dark")
fmri = sns.load_dataset("fmri")
  
# Plot the responses for different\
# events and regions
#sns.lineplot(x="timepoint",
             #y="signal",
             #hue="region",
             #style="event",
             #data=fmri,
            #color = "black")
sns.lineplot(x="timepoint", 
            y="signal",
             hue="region",
             style="event",
             data=fmri,
             color="black")
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
# To check the parameters of seaborn..
# https://www.geeksforgeeks.org/python-seaborn-pairplot-method/?ref=rp

# %%
# Changing the figure Size
# The figure size can be changed using the figure() method of Matplotlib. figure() method creates a new figure of the specified size passed in the figsize parameter.

# %% [markdown]
# #  Color Palette

# %%
# importing packages 
import seaborn as sns 
import matplotlib.pyplot as plt
  
# current colot palette
palette = sns.color_palette('ocean_r')
  
# plots the color palette as a
# horizontal array
sns.palplot(palette)
  
plt.show()

# %% [markdown]
# # Seaborn also provides some functions for plotting multiple plots

# %% [markdown]
# ##  FacetGrid class helps in visualizing distribution of one variable as well as the relationship between multiple variables
#
# ## separately within subsets of your dataset using multiple panels.

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt
  
# loading dataset
data = sns.load_dataset("iris")
print(data.head(2)) 
data.columns
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
plot = sns.FacetGrid(data, col="species") # Used for multivariate analysis. 
plot.map(plt.scatter, "sepal_width","petal_length","sepal_length")
plt.show()

# %% [markdown]
# #  Using PairGrid() method
#
# ## This class maps each variable in a dataset onto a column and row in a grid of multiple axes. Different axes-level plotting functions can be used to draw bivariate plots

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt
  
# loading dataset
data = sns.load_dataset("iris")
  
plot = sns.PairGrid(data) # Used for Bivariate Analysis
plot.map(plt.plot)
  
plt.show()

# %% [markdown]
# #  Categorical Plots

# %% [markdown]
# # Distplot
#
# * Distplot is used basically for univariant set of observations and visualizes it through a histogram i.e. only one observation and hence we choose one particular column of the dataset. It is potted using the distplot() method.

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt
  
# loading dataset
data = sns.load_dataset("iris")
  
sns.distplot(data['sepal_width'])
plt.show()

# %% [markdown]
# # Pairplot
#
# * Pairplot represents pairwise relation across the entire dataframe and supports an additional argument called hue for categorical separation.
# * What it does basically is create a jointplot between every possible numerical column and takes a while if the dataframe is really huge.
# * It is plotted using the pairplot() method.

# %%
# importing packages

import seaborn as sns
import matplotlib.pyplot as plt
  
# loading dataset
data = sns.load_dataset("titanic")
#data.columns  
sns.pairplot(data=data, hue='sex')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
# It says as your sepal width increses the petal length also increses..
# - value says if one is incresing the other one decreses..

# %% [markdown]
# # Heatmap

# %%
a = pd.DataFrame({"a":[1,2,3,4],"b":[11,22,33,44]})
sns.heatmap(a,annot = True,fmt=".1f",
            linewidth=.99,cmap="crest",vmin=50, vmax=5)
# Out:
# <AxesSubplot:>

# %%
data = sns.load_dataset("titanic")
data.columns
plt.figure(figsize=(20,40))
#df = data.drop('species',axis = 1)
sns.heatmap(df,annot = True,cmap = 'tab20c')
# Out:
# <AxesSubplot:>

# %%
Shubham(22)
# Out:
# My age is 22

# %%
df = sns.load_dataset("titanic")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x='sex', y='tip', data=sns.load_dataset('tips'))
plt.title("Tip Amount by Gender")
plt.show()

# %%
sns.countplot(x='day', data=sns.load_dataset('tips'))
plt.title("Number of Customers by Weekday")
plt.show()

# %%
sns.countplot(x='time', data=sns.load_dataset('tips'))
plt.title("Meal Preference (Lunch vs. Dinner)")
plt.show()

# %%
sns.boxplot(x='day', y='size', data=sns.load_dataset('tips'))
plt.title("Crowd Size by Weekday")
plt.show()

# %%
sns.boxplot(x='time', y='tip', hue='sex', data=sns.load_dataset('tips'))
plt.title("Tips by Gender and Time (Lunch vs. Dinner)")
plt.show()
